# %% [markdown]
# <a href="https://colab.research.google.com/github/samantha-isaac/Emotion-Detection-in-Images-and-Music-Pairing-Through-AI/blob/main/CNN_Best_FaceExpression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CNNs Fine Tuned for Face Expression Dataset
#
# Samantha Isaac

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dropout, Flatten, Dense, MaxPooling2D, Conv2D, Input, Activation
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import LeakyReLU
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.optimizers import Adam
import seaborn as sns
import os
import cv2
from google.colab import drive
import matplotlib.pyplot as plt
from collections import Counter

# %%
# This is to mount Drive to this project
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Connect to My Drive
# %cd /content/drive/My Drive/
# Out:
# /content/drive/My Drive

# %%
# Paths to the folder for the Face expressions dataset
training_dataset_folder = '/content/drive/MyDrive/Dissertation/Code/Data_Faces/Training'
testing_dataset_folder = '/content/drive/MyDrive/Dissertation/Code/Data_Faces/Testing'

# %%
# This function helps load the images and assigns as the labels the name of the correspodning folder
# References used for the function with os: https://docs.python.org/3/library/os.html
def load_images_and_labels(folder_path):
    images = []
    labels = []
    sub_folders = os.listdir(folder_path)

    for sub_folder in sub_folders:
        label = sub_folder  # In here is where the name of the sub folders is taken as the label
        image_files = os.listdir(os.path.join(folder_path, sub_folder))

        for image_file in image_files:
            image_path = os.path.join(folder_path, sub_folder, image_file)
            # This is to load the images in grey scale
            image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE) # Reference for this: https://docs.opencv.org/4.x/d4/da8/group__imgcodecs.html
            if image is not None:
                images.append(image)
                labels.append(label)

    return images, labels

# %%
# To load training images and labels
training_images, training_labels = load_images_and_labels(training_dataset_folder)

# To load testing images and labels
testing_images, testing_labels = load_images_and_labels(testing_dataset_folder)

# %%
# Convert tag lists into sets to view unique tags
training_labels_unique = set(training_labels)
testing_labels_unique = set(testing_labels)

# I print them to verify that the labels were properly assigned
print("Unique labels in the training set:", training_labels_unique)
print("Unique labels in the test set:", testing_labels_unique)

# To verify the total amount of images per label. Reference from: https://docs.python.org/3/library/collections.html#collections.Counter
training_labels_count = Counter(training_labels)
testing_labels_count = Counter(testing_labels)

print("\nNumber of images per class in the training set:")
for label, count in training_labels_count.items():
    print(f"{label}: {count}")

print("\nNumber of images per class in the testing set:")
for label, count in testing_labels_count.items():
    print(f"{label}: {count}")

# This is to show a few images to visually verify the images and the labels
def show_images_per_class(images, labels, clase, num_imagenes=3):
    print(f"\nShowing images of the class: {clase}") # This line was added to explicitatly indicate which images are being shown
    fig, axes = plt.subplots(1, num_imagenes, figsize = (10, 3)) # Reference from: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html
    # This is to create a list of the specific images
    imagenes_clase = [img for img, lbl in zip(images, labels) if lbl == clase]

# This is to iterate and take only the specific number of images, which is 3
    for i in range(num_imagenes):
        if i < len(imagenes_clase):
            axes[i].imshow(imagenes_clase[i], cmap = 'gray') # To show the images in grey scale
            axes[i].axis('off') # To hide the number and borders of the axis. Reference from: https://www.geeksforgeeks.org/how-to-turn-off-the-axes-for-subplots-in-matplotlib/
            # To add title with the corresponding label of each image
            axes[i].set_title(clase, fontsize = 10)
        else:
            axes[i].axis('off')

# It does this for both training and testing dataset
for label in training_labels_unique:
    show_images_per_class(training_images, training_labels, label)

for label in testing_labels_unique:
    show_images_per_class(testing_images, testing_labels, label)
# Out:
# Unique labels in the training set: {'Fear', 'Angry', 'Sad', 'Happy', 'Neutral'}
# Unique labels in the test set: {'Fear', 'Angry', 'Sad', 'Happy', 'Neutral'}
#
# Number of images per class in the training set:
# Angry: 3995
# Fear: 4097
# Happy: 7215
# Neutral: 4965
# Sad: 4830
#
# Number of images per class in the testing set:
# Angry: 958
# Fear: 1020
# Happy: 1774
# Neutral: 1233
# Sad: 1247
#
# Showing images of the class: Fear
#
# Showing images of the class: Angry
#
# Showing images of the class: Sad
#
# Showing images of the class: Happy
#
# Showing images of the class: Neutral
#
# Showing images of the class: Fear
#
# Showing images of the class: Angry
#
# Showing images of the class: Sad
#
# Showing images of the class: Happy
#
# Showing images of the class: Neutral

# %%
# Convert labels to numerical format
label_map = {label: idx for idx, label in enumerate(set(training_labels))}
training_labels_numeric = [label_map[label] for label in training_labels]
testing_labels_numeric = [label_map[label] for label in testing_labels]

# %%
# Just to verify the labels with the index assigened to it
print("Contents of the label_map dictionary:")
for label, index in label_map.items():
    print(f"'{label}': {index}")
# Out:
# Contents of the label_map dictionary:
# 'Fear': 0
# 'Angry': 1
# 'Sad': 2
# 'Happy': 3
# 'Neutral': 4

# %%
# Convert labels to one-hot encoding. Reference from: https://www.tensorflow.org/api_docs/python/tf/keras/utils/to_categorical
num_classes = len(label_map)
training_labels_y_encoded = to_categorical(training_labels_numeric, num_classes=num_classes)
testing_labels_y_encoded = to_categorical(testing_labels_numeric, num_classes=num_classes)

# %%
# To normalize and to convert in arrays of NumPy. Reference from: https://numpy.org/doc/stable/reference/generated/numpy.array.html
training_images_x = np.array(training_images) / 255.0
testing_images_x = np.array(testing_images) / 255.0

# %%
# This is to reshape images to add channel dimension. Reference: https://numpy.org/doc/stable/reference/generated/numpy.reshape.html
training_images_x = training_images_x.reshape(-1, 48, 48, 1)
testing_images_x = testing_images_x.reshape(-1, 48, 48, 1)

# %%
# This was an extra added to improve the generalisability of the model, generating new modified versions of the images
datagen = ImageDataGenerator(
    rotation_range = 10,
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    zoom_range = 0.1,
    horizontal_flip = True
)

datagen.fit(training_images_x)

# %%
# Stablish the structure of the CNN model. Used a reference for most of the structure of the models
# the project of: https://medium.com/@skillcate/emotion-detection-model-using-cnn-a-complete-guide-831db1421fael
input = Input(shape = (48, 48, 1))
conv1 = Conv2D(32, (3, 3), padding = 'same', strides = (1, 1), kernel_regularizer = l2(0.001))(input)
conv1 = LeakyReLU(alpha = 0.01)(conv1)
conv1 = Dropout(0.3)(conv1)
pool1 = MaxPooling2D(pool_size = (2, 2))(conv1)

conv2 = Conv2D(64, (3, 3), padding = 'same', strides = (1, 1), kernel_regularizer = l2(0.001))(pool1)
conv2 = LeakyReLU(alpha = 0.01)(conv2)
conv2 = Dropout(0.3)(conv2)
pool2 = MaxPooling2D(pool_size = (2, 2))(conv2)

conv3 = Conv2D(128, (3, 3), padding = 'same', strides = (1, 1), kernel_regularizer = l2(0.001))(pool2)
conv3 = LeakyReLU(alpha = 0.01)(conv3)
conv3 = Dropout(0.4)(conv3)
pool3 = MaxPooling2D(pool_size = (2, 2))(conv3)

conv4 = Conv2D(256, (3, 3), padding = 'same', strides = (1, 1), kernel_regularizer = l2(0.001))(pool3)
conv4 = LeakyReLU(alpha = 0.01)(conv4)
conv4 = Dropout(0.4)(conv4)
pool4 = MaxPooling2D(pool_size = (2, 2))(conv4)

flatten = Flatten()(pool4)
dense_1 = Dense(128, activation = 'relu')(flatten)
drop_1 = Dropout(0.5)(dense_1)
output = Dense(num_classes, activation = "softmax")(drop_1)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(

# %%
optimizer = Adam(learning_rate = 0.0001)
# To compile the model. Reference: https://www.tensorflow.org/api_docs/python/tf/keras/Model
model = Model(inputs = input, outputs = output)
model.compile(optimizer = optimizer, loss = "categorical_crossentropy", metrics = ['accuracy'])
model.summary() # I get a summary of the model architecture. Reference: https://stackoverflow.com/questions/36946671/keras-model-summary-result-understanding-the-of-parameters
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)           │ (None, 48, 48, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_8 (Conv2D)                    │ (None, 48, 48, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_4 (LeakyReLU)            │ (None, 48, 48, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_10 (Dropout)                 │ (None, 48, 48, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_8 (MaxPooling2D)       │ (None, 24, 24, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_9 (Conv2D)                    │ (None, 24, 24, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_5 (LeakyReLU)            │ (None, 24, 24, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_11 (Dropout)                 │ (None, 24, 24, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_9 (MaxPooling2D)       │ (None, 12, 12, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_10 (Conv2D)                   │ (None, 12, 12, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_6 (LeakyReLU)            │ (None, 12, 12, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_12 (Dropout)                 │ (None, 12, 12, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_10 (MaxPooling2D)      │ (None, 6, 6, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_11 (Conv2D)                   │ (None, 6, 6, 256)           │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_7 (LeakyReLU)            │ (None, 6, 6, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_13 (Dropout)                 │ (None, 6, 6, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_11 (MaxPooling2D)      │ (None, 3, 3, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 2304)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 128)                 │         295,040 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_14 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 5)                   │             645 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 683,525 (2.61 MB)
#  Trainable params: 683,525 (2.61 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# I stablished a checkpoint to save as well the model in the selected location. Reference: https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/ModelCheckpoint
fle_s = './output/emotion_model_baseline_v3.keras'
checkpointer = ModelCheckpoint(
    fle_s,
    monitor = 'val_loss',
    verbose = 1,
    save_best_only = True,
    save_weights_only = False,
    mode = 'auto',
    save_freq = 'epoch'
)

# %%
# Stablish earlystopping. Reference: https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/EarlyStopping
early_stopping = EarlyStopping(
    monitor = 'val_loss',
    patience = 10,
    verbose = 1,
    restore_best_weights = True
)

# %%
# Callback list
callback_list = [checkpointer, early_stopping]

# %%
# To train the model, and I specdify the parameters to use. Reference: https://stackoverflow.com/questions/37973005/what-do-model-predict-and-model-fit-do
history = model.fit(
    training_images_x,
    training_labels_y_encoded,
    validation_data = (testing_images_x, testing_labels_y_encoded),
    epochs = 50,
    batch_size = 32,
    callbacks = callback_list
)
# Out:
# Epoch 1/50
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2889 - loss: 1.8246
# Epoch 1: val_loss improved from inf to 1.72406, saving model to ./output/emotion_model_baseline_v3.keras
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - accuracy: 0.2889 - loss: 1.8245 - val_accuracy: 0.3251 - val_loss: 1.7241
# Epoch 2/50
# 781/785 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3430 - loss: 1.6598
# Epoch 2: val_loss improved from 1.72406 to 1.63199, saving model to ./output/emotion_model_baseline_v3.keras
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.3431 - loss: 1.6596 - val_accuracy: 0.4048 - val_loss: 1.6320
# Epoch 3/50
# 780/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4062 - loss: 1.5375
# Epoch 3: val_loss improved from 1.63199 to 1.56220, saving model to ./output/emotion_model_baseline_v3.keras
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.4063 - loss: 1.5373 - val_accuracy: 0.4341 - val_loss: 1.5622
# Epoch 4/50
# 781/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4356 - loss: 1.4683
# Epoch 4: val_loss improved from 1.56220 to 1.51896, saving model to ./output/emotion_model_baseline_v3.keras
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.4357 - loss: 1.4682 - val_accuracy: 0.4681 - val_loss: 1.5190
# Epoch 5/50
# 777/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4608 - loss: 1.4083
# Epoch 5: val_loss improved from 1.51896 to 1.47630, saving model to ./output/emotion_model_baseline_v3.keras
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.4608 - loss: 1.4082 - val_accuracy: 0.4904 - val_loss: 1.4763
# Epoch 6/50
# 780/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4766 - loss: 1.3629
# Epoch 6: val_loss improved from 1.47630 to 1.45769, saving model to ./output/emotion_model_baseline_v3.keras
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.4766 - loss: 1.3628 - val_accuracy: 0.4928 - val_loss: 1.4577
# Epoch 7/50
# 776/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4967 - loss: 1.3335
# Epoch 7: val_loss improved from 1.45769 to 1.42499, saving model to ./output/emotion_model_baseline_v3.keras
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.4968 - loss: 1.3335 - val_accuracy: 0.5154 - val_loss: 1.4250
# Epoch 8/50
# 774/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5113 - loss: 1.3013
# Epoch 8: val_loss improved from 1.42499 to 1.40538, saving model to ./output/emotion_model_baseline_v3.keras
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5113 - loss: 1.3013 - val_accuracy: 0.5098 - val_loss: 1.4054
# Epoch 9/50
# 774/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5294 - loss: 1.2674
# Epoch 9: val_loss improved from 1.40538 to 1.38816, saving model to ./output/emotion_model_baseline_v3.keras
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5293 - loss: 1.2676 - val_accuracy: 0.5091 - val_loss: 1.3882
# Epoch 10/50
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5292 - loss: 1.2578
# Epoch 10: val_loss improved from 1.38816 to 1.37666, saving model to ./output/emotion_model_baseline_v3.keras
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5292 - loss: 1.2578 - val_accuracy: 0.5149 - val_loss: 1.3767
# Epoch 11/50
# 777/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5392 - loss: 1.2424
# Epoch 11: val_loss improved from 1.37666 to 1.34291, saving model to ./output/emotion_model_baseline_v3.keras
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5392 - loss: 1.2424 - val_accuracy: 0.5392 - val_loss: 1.3429
# Epoch 12/50
# 777/785 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5480 - loss: 1.2162
# Epoch 12: val_loss improved from 1.34291 to 1.34266, saving model to ./output/emotion_model_baseline_v3.keras
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5480 - loss: 1.2162 - val_accuracy: 0.5247 - val_loss: 1.3427
# Epoch 13/50
# 780/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5497 - loss: 1.2052
# Epoch 13: val_loss improved from 1.34266 to 1.31877, saving model to ./output/emotion_model_baseline_v3.keras
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5497 - loss: 1.2053 - val_accuracy: 0.5454 - val_loss: 1.3188
# Epoch 14/50
# 778/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5715 - loss: 1.1952
# Epoch 14: val_loss improved from 1.31877 to 1.30777, saving model to ./output/emotion_model_baseline_v3.keras
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5714 - loss: 1.1951 - val_accuracy: 0.5491 - val_loss: 1.3078
# Epoch 15/50
# 775/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5661 - loss: 1.1802
# Epoch 15: val_loss improved from 1.30777 to 1.30346, saving model to ./output/emotion_model_baseline_v3.keras
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5661 - loss: 1.1801 - val_accuracy: 0.5573 - val_loss: 1.3035
# Epoch 16/50
# 781/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5703 - loss: 1.1778
# Epoch 16: val_loss improved from 1.30346 to 1.28622, saving model to ./output/emotion_model_baseline_v3.keras
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5704 - loss: 1.1777 - val_accuracy: 0.5619 - val_loss: 1.2862
# Epoch 17/50
# 779/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5821 - loss: 1.1538
# Epoch 17: val_loss did not improve from 1.28622
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5820 - loss: 1.1538 - val_accuracy: 0.5647 - val_loss: 1.2970
# Epoch 18/50
# 781/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5782 - loss: 1.1540
# Epoch 18: val_loss improved from 1.28622 to 1.25992, saving model to ./output/emotion_model_baseline_v3.keras
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5782 - loss: 1.1540 - val_accuracy: 0.5735 - val_loss: 1.2599
# Epoch 19/50
# 781/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5862 - loss: 1.1334
# Epoch 19: val_loss did not improve from 1.25992
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5862 - loss: 1.1334 - val_accuracy: 0.5509 - val_loss: 1.2686
# Epoch 20/50
# 779/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5976 - loss: 1.1184
# Epoch 20: val_loss did not improve from 1.25992
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5976 - loss: 1.1185 - val_accuracy: 0.5651 - val_loss: 1.2680
# Epoch 21/50
# 777/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6010 - loss: 1.1232
# Epoch 21: val_loss improved from 1.25992 to 1.23111, saving model to ./output/emotion_model_baseline_v3.keras
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6010 - loss: 1.1231 - val_accuracy: 0.5661 - val_loss: 1.2311
# Epoch 22/50
# 780/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6040 - loss: 1.1091
# Epoch 22: val_loss did not improve from 1.23111
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6040 - loss: 1.1091 - val_accuracy: 0.5807 - val_loss: 1.2551
# Epoch 23/50
# 780/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6078 - loss: 1.0962
# Epoch 23: val_loss did not improve from 1.23111
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6078 - loss: 1.0962 - val_accuracy: 0.5846 - val_loss: 1.2442
# Epoch 24/50
# 784/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6139 - loss: 1.0843
# Epoch 24: val_loss improved from 1.23111 to 1.22911, saving model to ./output/emotion_model_baseline_v3.keras
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6139 - loss: 1.0843 - val_accuracy: 0.5685 - val_loss: 1.2291
# Epoch 25/50
# 781/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6175 - loss: 1.0719
# Epoch 25: val_loss improved from 1.22911 to 1.22668, saving model to ./output/emotion_model_baseline_v3.keras
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6175 - loss: 1.0719 - val_accuracy: 0.5879 - val_loss: 1.2267
# Epoch 26/50
# 781/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6177 - loss: 1.0815
# Epoch 26: val_loss did not improve from 1.22668
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6177 - loss: 1.0815 - val_accuracy: 0.5794 - val_loss: 1.2329
# Epoch 27/50
# 783/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6291 - loss: 1.0619
# Epoch 27: val_loss improved from 1.22668 to 1.20935, saving model to ./output/emotion_model_baseline_v3.keras
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6291 - loss: 1.0620 - val_accuracy: 0.5892 - val_loss: 1.2093
# Epoch 28/50
# 780/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6355 - loss: 1.0522
# Epoch 28: val_loss did not improve from 1.20935
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6355 - loss: 1.0522 - val_accuracy: 0.5806 - val_loss: 1.2297
# Epoch 29/50
# 780/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6370 - loss: 1.0457
# Epoch 29: val_loss did not improve from 1.20935
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6370 - loss: 1.0458 - val_accuracy: 0.5996 - val_loss: 1.2117
# Epoch 30/50
# 778/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6324 - loss: 1.0463
# Epoch 30: val_loss did not improve from 1.20935
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6324 - loss: 1.0462 - val_accuracy: 0.5927 - val_loss: 1.2273
# Epoch 31/50
# 778/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6514 - loss: 1.0224
# Epoch 31: val_loss improved from 1.20935 to 1.20128, saving model to ./output/emotion_model_baseline_v3.keras
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6513 - loss: 1.0224 - val_accuracy: 0.5866 - val_loss: 1.2013
# Epoch 32/50
# 781/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6422 - loss: 1.0338
# Epoch 32: val_loss improved from 1.20128 to 1.19121, saving model to ./output/emotion_model_baseline_v3.keras
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6422 - loss: 1.0338 - val_accuracy: 0.5878 - val_loss: 1.1912
# Epoch 33/50
# 779/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6485 - loss: 1.0148
# Epoch 33: val_loss improved from 1.19121 to 1.18203, saving model to ./output/emotion_model_baseline_v3.keras
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6485 - loss: 1.0149 - val_accuracy: 0.5968 - val_loss: 1.1820
# Epoch 34/50
# 775/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6562 - loss: 1.0036
# Epoch 34: val_loss did not improve from 1.18203
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6562 - loss: 1.0037 - val_accuracy: 0.5870 - val_loss: 1.1948
# Epoch 35/50
# 781/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6621 - loss: 0.9917
# Epoch 35: val_loss did not improve from 1.18203
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6621 - loss: 0.9918 - val_accuracy: 0.5876 - val_loss: 1.1927
# Epoch 36/50
# 781/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6617 - loss: 0.9882
# Epoch 36: val_loss did not improve from 1.18203
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6617 - loss: 0.9882 - val_accuracy: 0.5921 - val_loss: 1.1930
# Epoch 37/50
# 783/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6710 - loss: 0.9685
# Epoch 37: val_loss did not improve from 1.18203
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6710 - loss: 0.9685 - val_accuracy: 0.5952 - val_loss: 1.1904
# Epoch 38/50
# 781/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6682 - loss: 0.9826
# Epoch 38: val_loss improved from 1.18203 to 1.17635, saving model to ./output/emotion_model_baseline_v3.keras
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6683 - loss: 0.9826 - val_accuracy: 0.6057 - val_loss: 1.1763
# Epoch 39/50
# 780/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6794 - loss: 0.9626
# Epoch 39: val_loss improved from 1.17635 to 1.17537, saving model to ./output/emotion_model_baseline_v3.keras
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6794 - loss: 0.9627 - val_accuracy: 0.6072 - val_loss: 1.1754
# Epoch 40/50
# 777/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6832 - loss: 0.9600
# Epoch 40: val_loss improved from 1.17537 to 1.17253, saving model to ./output/emotion_model_baseline_v3.keras
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6832 - loss: 0.9601 - val_accuracy: 0.5953 - val_loss: 1.1725
# Epoch 41/50
# 781/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6862 - loss: 0.9447
# Epoch 41: val_loss did not improve from 1.17253
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6861 - loss: 0.9448 - val_accuracy: 0.6013 - val_loss: 1.2006
# Epoch 42/50
# 777/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6881 - loss: 0.9386
# Epoch 42: val_loss did not improve from 1.17253
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6881 - loss: 0.9387 - val_accuracy: 0.5961 - val_loss: 1.1783
# Epoch 43/50
# 782/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6886 - loss: 0.9365
# Epoch 43: val_loss improved from 1.17253 to 1.16586, saving model to ./output/emotion_model_baseline_v3.keras
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6886 - loss: 0.9365 - val_accuracy: 0.6021 - val_loss: 1.1659
# Epoch 44/50
# 781/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6927 - loss: 0.9307
# Epoch 44: val_loss did not improve from 1.16586
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6926 - loss: 0.9308 - val_accuracy: 0.5990 - val_loss: 1.1777
# Epoch 45/50
# 780/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6962 - loss: 0.9259
# Epoch 45: val_loss did not improve from 1.16586
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6962 - loss: 0.9260 - val_accuracy: 0.6029 - val_loss: 1.1785
# Epoch 46/50
# 784/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6966 - loss: 0.9199
# Epoch 46: val_loss did not improve from 1.16586
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6966 - loss: 0.9199 - val_accuracy: 0.6024 - val_loss: 1.1743
# Epoch 47/50
# 781/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7047 - loss: 0.9160
# Epoch 47: val_loss did not improve from 1.16586
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7047 - loss: 0.9160 - val_accuracy: 0.5964 - val_loss: 1.1770
# Epoch 48/50
# 780/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7146 - loss: 0.8964
# Epoch 48: val_loss did not improve from 1.16586
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7145 - loss: 0.8965 - val_accuracy: 0.6070 - val_loss: 1.1718
# Epoch 49/50
# 777/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7138 - loss: 0.8923
# Epoch 49: val_loss did not improve from 1.16586
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7137 - loss: 0.8924 - val_accuracy: 0.6082 - val_loss: 1.1721
# Epoch 50/50
# 780/785 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7131 - loss: 0.8943
# Epoch 50: val_loss did not improve from 1.16586
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7131 - loss: 0.8943 - val_accuracy: 0.5987 - val_loss: 1.1730
# Restoring model weights from the end of the best epoch: 43.

# %%
# This is to visualise the model throughout the training, where accuracy and loss are shown for both training sets
# Reference: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show();

# %%
# This is to evaluate as well the performance of the model with a confusion matrix and a clasification report
# This is for the model to make prediction on the testing images. Reference: https://www.tensorflow.org/api_docs/python/tf/keras/Model
y_pred = model.predict(testing_images_x)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(testing_labels_y_encoded, axis=1)

# Convert the numeric labels back to text labels
index_to_label = {v: k for k, v in label_map.items()}
y_true_labels = [index_to_label[i] for i in y_true]
y_pred_labels = [index_to_label[i] for i in y_pred_classes]

# Define a consistent order for the labels, which is in alphabetical order
label_order = sorted(list(label_map.keys()))

# This is for the confusion matrix. Reference: https://proclusacademy.com/blog/practical/confusion-matrix-accuracy-sklearn-seaborn/
cm = confusion_matrix(y_true_labels, y_pred_labels, labels=label_order)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True,
            fmt='d',
            cmap='Blues',
            xticklabels=label_order,
            yticklabels=label_order)

plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show();

# Show classification report
print("Clasification report:")
print(classification_report(y_true_labels, y_pred_labels, target_names=label_order))
# Out:
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Clasification report:
#               precision    recall  f1-score   support
#
#        Angry       0.62      0.45      0.52       958
#      Neutral       0.53      0.61      0.57      1233
#        Happy       0.79      0.86      0.82      1774
#         Fear       0.61      0.31      0.41      1020
#          Sad       0.44      0.59      0.50      1247
#
#     accuracy                           0.60      6232
#    macro avg       0.60      0.56      0.57      6232
# weighted avg       0.61      0.60      0.59      6232

# %%
# !ls ./output/ # This is to check if the model was sabed properly
# Out:
# emotion_model_baseline_v1.keras  emotion_model_baseline_v3.keras
# emotion_model_baseline_v2.keras  emotion_model_baseline_v4.keras
